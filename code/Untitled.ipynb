# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/combined_test_scores_and_public_spending_17_19.csv')

p_mask = df['participation_act'] > 0.75
p_df = df[p_mask]
p_corr = p_df.corr()['state_and_local_spending_welfare'].sort_values(ascending=False)
p_df_corr = pd.DataFrame(data=p_corr,
             index=p_corr.index,
             columns=['state_and_local_spending_welfare']
            )

# %%
plt.figure(figsize=(12,12))
sns.heatmap(p_df,
            annot=True,
            vmin=-1, 
            vmax=1,
            cmap='bone'
           )
# Out:
# <AxesSubplot:>

# %%
p_mask = df['participation_sat'] > 0.75
p_df = df[p_mask]
p_corr = p_df.corr()['local_spending_welfare'].sort_values(ascending=False)
p_df = pd.DataFrame(data=p_corr,
             index=p_corr.index,
             columns=['local_spending_welfare']
            )
plt.figure(figsize=(12,12))
sns.heatmap(p_df,
            annot=True,
            vmin=-1, 
            vmax=1,
            cmap='bone'
           )
# Out:
# <AxesSubplot:>

# %%
p_df.columns
# Out:
# Index(['state_and_local_spending_welfare'], dtype='object')

# %%
sns.regplot(x=p_df['state_and_local_spending_welfare'],
            y=p_df['']
           )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'composite_act'
#
# The above exception was the direct cause of the following exception:
#
# ...
