# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# #### Contextualizing the Problem

# %% [markdown]
# While the many studies that have called into question the usefulness of standardized testing as a measure of student potential and ability have their merits, as long as these tests remain one of the primary tools that colleges and universities employ to evaluate student acheievement, we cannot neglect to expolore the most promising aveneues for making these measures more equitable and more representative of student potential. One of the primary ways that policy makers can approach this question is by analyzing the relationships between public funding and student achievement.

# %% [markdown]
# I am seeking to explore whether there are general trends that exist between public spending on education and welfare and student achievement on the SAT and ACT. Does higher per capita spending on education translate to higher average test scores, especially in the states that consistently perform at the lowest levels? Does public welfare spending per capita follow a similar trend? Is either education or public welfare more closely aligned with student achievement? And, given the trends analyzed above, where would resources be most effectively allocated to conduct further research into improving student achievement for the most disadvantaged students?

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# function that calculates the mean of values in an iterable
def calc_mean(values):
    return sum(values) / len(values)

# %%
values_list = [2, 3, 4, 5, 6, 7, 8]

calc_mean(values_list)
# Out:
# 5.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def s_dev(values):
    m = calc_mean(values)
    n = len(values)
    
    return (sum([(x - m)**2 for x in values]) / (n -1))**0.5

# %%
values_list = [1, 2, 4, 5]
s_dev(values_list)
# Out:
# 1.8257418583505538

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# function that takes in percentages as a string with the percent symbol "%" and returns a float: input: 15% return: 0.15

def percent_to_float(percentage):
    return float(percentage.replace("%", '')) / 100

# %%
percentage_30 = "30%"

percent_to_float(percentage_30)
# Out:
# 0.3

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# #### Helper Functions

# %%
# Idea from stackoverflow: https://stackoverflow.com/a/592891
# Returns a list of strings of the variable name(s) assigned to a given object. I use this to get information on several dataframes simultaneously while keeping outputs readable
def namestr(obj, namespace=globals()):
    """This function returns the name(s) of the variable(s) to which a given object has been assigned. The namespace defaults to globals()"""
    
    return [name for name in namespace if namespace[name] is obj]

# %%
# Helper function to check nulls in a list of DataFrames and return outputs in a readable format

def check_nulls(df_list):
    
    for df in df_list:
        s = namestr(df)[0]
        t = df.isnull().sum().sum()
        n = df.isnull().sum()
        
        if t == 0:
            print(s)
            print('null values: 0')
            print('\n')
        
        else:
            print(s)
            print(n)
            print('\n')

# %%
# This function takes a list of dataframes and drops rows with null values in all of the DataFrames.

def bulk_drop_na(df_list):
    """***USE WITH CAUTION*** Takes a list of DataFrames and drops all rows in all DataFrames that contain null values."""
   
    for df in df_list:
        df.dropna(inplace=True)

# %%
# This function takes in a list of dataframes and checks the data types of all features with a readable output
def check_dtypes(df_list):
    for df in df_list:
        print(namestr(df)[0])
        print(df.dtypes)
        print('\n')

# %%
def dollar_to_float(df_list):
    for df in df_list:
        for column in df.columns:
            if 'spending' in column.lower() or 'product' in column.lower():
                if df[column].dtype == 'object':
                    df[column] = df[column].apply(lambda x: float(x.replace(',', '')))
    return check_dtypes(df_list)

# %%
# This function takes a list of dataframes and drops all columns with "unnamed" in the column name or with only a space
def drop_unnamed_cols(df_list):
    for df in df_list:
        drop_cols = [x for x in df.columns if 'unnamed' in x.lower() or x == ' ']
        df.drop(columns=drop_cols, inplace=True)
        print(namestr(df)[0])
        print(f'dropped {drop_cols}\n\n')

# %%
# This function drops all non total/composite test score columns from test score dataframes

def drop_sections(df_list):
    for df in df_list:
        drop_cols = [x for x in df.columns if 'total' not in x.lower() and 'composite' not in x.lower() and 'state' not in x.lower() and 'participation' not in x.lower()]
        df.drop(columns=drop_cols, inplace=True)
        print(namestr(df)[0])
        print(f'dropped: {drop_cols}')

# %% [markdown]
# #### Import & View Data

# %%
# SAT Scores by State 2017-2019
sat_19 = pd.read_csv('../data/sat_2019.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')
sat_17 = pd.read_csv('../data/sat_2017.csv')

# ACT Scores by State 2017-2019
act_19 = pd.read_csv('../data/act_2019.csv')
act_18 = pd.read_csv('../data/act_2018.csv')
act_17 = pd.read_csv('../data/act_2017.csv')

# Education Spending by State 2017-2019
ed_19 = pd.read_csv('../data/education_usgs_state_2019.csv', skiprows=6)
ed_18 = pd.read_csv('../data/education_usgs_state_2018.csv', skiprows=6)
ed_17 = pd.read_csv('../data/education_usgs_state_2017.csv', skiprows=6)

# Welfare Spending by State 2017-2019
wf_19 = pd.read_csv('../data/welfare_usgs_state_2019.csv', skiprows=6)
wf_18 = pd.read_csv('../data/welfare_usgs_state_2018.csv', skiprows=6)
wf_17 = pd.read_csv('../data/welfare_usgs_state_2017.csv', skiprows=6)

# %%
# Create lists of dataframes to pass into helper functions

# Create list of SAT score dataframes
sat_dfs = [sat_17, sat_18, sat_19]

# Create a list of ACT score dataframes
act_dfs = [act_17, act_18, act_19]

# Create a list education spending dataframes
ed_dfs = [ed_17, ed_18, ed_19]

# Create a list of welfare spending dataframes
wf_dfs = [wf_17, wf_18, wf_19]

# Create a list of all test score dataframes
# This method is from an example at: https://www.geeksforgeeks.org/python-ways-to-concatenate-two-lists/
score_dfs = [*sat_dfs, *act_dfs]

# Create a list of all spending dataframes
spending_dfs = [*ed_dfs, *wf_dfs]

# Create a list of all dataframes
all_dfs = [*score_dfs, *spending_dfs]

# %%
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
ed_17.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             6.2          a             7.9          a
# 1      Alaska             1.4          a             1.9          a
# 2     Arizona             5.7          a             9.6          a
# 3    Arkansas             3.2          a             5.2          a
# 4  California            36.0          a            96.8          a
#
#   State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                     14.2          a               215.1          a
# 1                      3.3          a                53.1          a
# 2                     15.3          a               330.4          a
# 3                      8.4          a               122.4          a
# 4                    132.8          a             2,731.0          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.7           a                   4.9  e
# ...

# %%
ed_18.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             6.7          a             8.1          a
# 1      Alaska             1.4          a             1.9          a
# 2     Arizona             6.0          a             9.9          a
# 3    Arkansas             3.4          a             5.4          a
# 4  California            38.2          a           104.5          a
#
#   State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                     14.8          a               224.0          a
# 1                      3.3          a                54.7          a
# 2                     16.0          a               349.9          a
# 3                      8.8          a               127.3          a
# 4                    142.7          a             2,895.1          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.6           a                   4.9  e
# ...

# %%
ed_19.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             6.9          a             8.3          a
# 1      Alaska             1.3          a             1.9          a
# 2     Arizona             6.2          a            11.0          a
# 3    Arkansas             3.4          a             5.6          a
# 4  California            44.6          a           108.9          a
#
#   State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                     15.2          a               231.2          a
# 1                      3.2          a                54.5          a
# 2                     17.2          a               370.0          a
# 3                      9.0          a               130.8          a
# 4                    153.5          a             3,052.7          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.3           a                   4.9  e
# ...

# %%
wf_17.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             2.3          a             0.6          a
# 1      Alaska             0.7          a             0.2          a
# 2     Arizona             3.6          a             0.5          a
# 3    Arkansas             0.8          a             0.2          a
# 4  California            16.5          a            26.5          a
#
#    State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                       2.8          a               215.1          a
# 1                       0.9          a                53.1          a
# 2                       4.1          a               330.4          a
# 3                       1.0          a               122.4          a
# 4                      43.1          a             2,731.0          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.7           a                   4.9  e
# ...

# %%
wf_18.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             1.1          a             0.6          a
# 1      Alaska             0.8          a             0.2          a
# 2     Arizona             3.6          a             0.5          a
# 3    Arkansas             0.8          a             0.2          a
# 4  California            16.9          a            27.9          a
#
#    State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                       1.6          a               224.0          a
# 1                       1.0          a                54.7          a
# 2                       4.1          a               349.9          a
# 3                       1.0          a               127.3          a
# 4                      44.8          a             2,895.1          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.6           a                   4.9  e
# ...

# %%
wf_19.head()
# Out:
#         State  State Spending Unnamed: 2  Local Spending Unnamed: 4  \
# 0     Alabama             1.2          a             0.5          a
# 1      Alaska             0.6          a             0.2          a
# 2     Arizona             3.8          a             0.5          a
# 3    Arkansas             0.8          a             0.2          a
# 4  California            17.5          a            28.9          a
#
#    State and Local Spending Unnamed: 6 Gross State Product Unnamed: 8  \
# 0                       1.7          a               231.2          a
# 1                       0.8          a                54.5          a
# 2                       4.3          a               370.0          a
# 3                       1.0          a               130.8          a
# 4                      46.4          a             3,052.7          a
#
#    Real State Growth % Unnamed: 10  Population (million)
# 0                  1.3           a                   4.9  e
# ...

# %% [markdown]
# #### Check for Missing/ Null Values

# %% [markdown]
# * Check for Missing Values

# %%
# Use check_nulls() to check for missing values in all dataframes in the all_dfs list

check_nulls(all_dfs)
# Out:
# sat_17
# null values: 0
#
#
# sat_18
# null values: 0
#
#
# sat_19
# null values: 0
#
#
# act_17
# null values: 0
#
#
# act_18
# null values: 0
#
#
# act_19
# null values: 0
#
#
# ed_17
# State                       0
# State Spending              3
# Unnamed: 2                  3
# Local Spending              3
# Unnamed: 4                  3
# State and Local Spending    3
# Unnamed: 6                  3
# Gross State Product         3
# Unnamed: 8                  3
# Real State Growth %         3
# Unnamed: 10                 3
# Population (million)        3
#                             3
# dtype: int64
#
#
# ed_18
# State                       0
# State Spending              3
# Unnamed: 2                  3
# Local Spending              3
# Unnamed: 4                  3
# State and Local Spending    3
# Unnamed: 6                  3
# Gross State Product         3
# Unnamed: 8                  3
# Real State Growth %         3
# Unnamed: 10                 3
# ...

# %% [markdown]
# * Drop Rows with Missing Values

# %%
# Drop the three rows without data (example below) in the Education Spending and Welfare Spending DataFrames

null_mask = ed_17['State Spending'].isnull()
ed_17[null_mask]
# Out:
#                                  State  State Spending Unnamed: 2  \
# 52                             Legend:             NaN        NaN
# 53                 a - actual reported             NaN        NaN
# 54  e - out-year estimate in US budget             NaN        NaN
#
#     Local Spending Unnamed: 4 State and Local Spending Unnamed: 6  \
# 52             NaN        NaN                      NaN        NaN
# 53             NaN        NaN                      NaN        NaN
# 54             NaN        NaN                      NaN        NaN
#
#    Gross State Product Unnamed: 8  Real State Growth % Unnamed: 10  \
# 52                 NaN        NaN                  NaN         NaN
# 53                 NaN        NaN                  NaN         NaN
# 54                 NaN        NaN                  NaN         NaN
#
#     Population (million)
# 52                   NaN  NaN
# 53                   NaN  NaN
# 54                   NaN  NaN

# %%
# Drop rows with null values in all gov/t spending DataFrames
bulk_drop_na(spending_dfs)

# %%
# Make sure all null values have been dropped
check_nulls(all_dfs)
# Out:
# sat_17
# null values: 0
#
#
# sat_18
# null values: 0
#
#
# sat_19
# null values: 0
#
#
# act_17
# null values: 0
#
#
# act_18
# null values: 0
#
#
# act_19
# null values: 0
#
#
# ed_17
# null values: 0
#
#
# ed_18
# null values: 0
#
#
# ed_19
# null values: 0
#
#
# wf_17
# null values: 0
#
#
# wf_18
# null values: 0
#
#
# wf_19
# null values: 0

# %% [markdown]
# #### Check Data Types

# %%
# use check_dtypes() function to view data types for all features in all dataframes

check_dtypes(all_dfs)
# Out:
# sat_17
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# sat_18
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# sat_19
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object
#
#
# act_17
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
#
#
# act_18
# State             object
# Participation     object
# ...

# %%
# View the count of all unique values in participation columns of test score dataframes

for df in score_dfs:
    print(namestr(df)[0])
    for column in df.columns:
        if 'Participation' in column:
            print(df[column].value_counts())
            print('\n')
# Out:
# sat_17
# 3%      8
# 100%    4
# 4%      3
# 2%      3
# 5%      2
# 11%     2
# 65%     2
# 7%      1
# 67%     1
# 49%     1
# 12%     1
# 71%     1
# 43%     1
# 96%     1
# 50%     1
# 62%     1
# 60%     1
# 64%     1
# 70%     1
# 76%     1
# 26%     1
# 10%     1
# 38%     1
# 69%     1
# 95%     1
# 63%     1
# 9%      1
# 93%     1
# 55%     1
# 61%     1
# 83%     1
# 53%     1
# 30%     1
# 14%     1
# Name: Participation, dtype: int64
#
#
# sat_18
# 4%      6
# 3%      6
# 100%    5
# 6%      2
# 56%     2
# 70%     2
# 99%     2
# 66%     1
# 64%     1
# 79%     1
# 55%     1
# 68%     1
# 69%     1
# 97%     1
# 48%     1
# 18%     1
# 8%      1
# 2%      1
# 52%     1
# 23%     1
# 16%     1
# 82%     1
# 96%     1
# 43%     1
# 10%     1
# 80%     1
# 76%     1
# 63%     1
# 92%     1
# 60%     1
# 5%      1
# 29%     1
# 28%     1
# Name: Participation, dtype: int64
#
#
# sat_19
# 100%    8
# 3%      6
# 4%      5
# 68%     3
# 66%     2
# —       2
# 70%     2
# ...

# %% [markdown]
# * Correct Invalid Entries for Participation Rates and Convert Strings to Floats

# %%
# view sat_19 participation values with "-" as the participation rate

mask = sat_19['Participation Rate'] == '—'
sat_19[mask]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935

# %%
# Drop rows for Puerto Rico and the Virgin Islands as they are outside of the scope of my problem statement. 

if sat_19.loc[39, 'State'] == 'Puerto Rico' and sat_19.loc[47, 'State'] == 'Virgin Islands':
    sat_19.drop(index=[39, 47], axis=0, inplace=True)
    sat_19.reset_index(drop=True, inplace=True)
else:
    pass

# %%
# Use percent to float function to convert all percent strings to floats in all test score dataframes

for df in score_dfs:
    for column in df.columns:
        if 'Participation' in column:
            df[column] = df[column].apply(lambda x: percent_to_float(x))

# %%
check_dtypes(score_dfs)
# Out:
# sat_17
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
#
# sat_18
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
#
# sat_19
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object
#
#
# act_17
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
#
#
# act_18
# State             object
# ...

# %%
# Use dollar_to_float() function to remove '$' and ',' from all columns in spending dataframes and convert strings to floats

dollar_to_float(spending_dfs)
# Out:
# ed_17
# State                        object
# State Spending              float64
# Unnamed: 2                   object
# Local Spending              float64
# Unnamed: 4                   object
# State and Local Spending    float64
# Unnamed: 6                   object
# Gross State Product         float64
# Unnamed: 8                   object
# Real State Growth %         float64
# Unnamed: 10                  object
# Population (million)        float64
#                              object
# dtype: object
#
#
# ed_18
# State                        object
# State Spending              float64
# Unnamed: 2                   object
# Local Spending              float64
# Unnamed: 4                   object
# State and Local Spending    float64
# Unnamed: 6                   object
# Gross State Product         float64
# Unnamed: 8                   object
# Real State Growth %         float64
# Unnamed: 10                  object
# Population (million)        float64
# ...

# %% [markdown]
# * Convert ACT 2017 Composite Score Data to Float

# %%
# View counts of unique values to see if there are any non-digit characters
act_17['Composite'].value_counts()
# Out:
# 20.3     3
# 19.8     3
# 21.4     3
# 24.1     2
# 21.8     2
# 21.9     2
# 20.4     2
# 24.2     2
# 23.6     2
# 19.4     2
# 19.7     2
# 20.7     1
# 23.8     1
# 20.5     1
# 24.0     1
# 23.7     1
# 22.0     1
# 19.1     1
# 23.9     1
# 25.5     1
# 17.8     1
# 18.7     1
# 21.0     1
# 18.6     1
# 21.5     1
# 25.4     1
# 19.2     1
# 24.3     1
# 19.5     1
# 20.0     1
# 21.7     1
# 22.6     1
# 22.3     1
# 19.0     1
# 25.2     1
# 20.8     1
# 22.8     1
# 20.2x    1
# Name: Composite, dtype: int64

# %%
# remove the 'x' and convert to a float
act_17['Composite'] = act_17['Composite'].apply(lambda x: float(x.replace('x', '')))

# %%
# Check to make sure column is now a float
act_17['Composite'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Check for Obvious Errors/Issues in Data

# %% [markdown]
# * Check Min and Max Scores
#
# *possible range for SAT Subjects: 400-800\
# possible range for SAT Total: 800-1600\
# possible range for ACT Subjects: 0-32\
# possible range for ACT Composite: 0-32*

# %%
# Check for values above max or below min thresholds and note unusual values like "-" as a percentage

for df in score_dfs:
    print('\n\n' + namestr(df)[0] + '\n')
    print('Minimum Values:\n', df.min(), '\n\nMaximum Values:\n', df.max())
# Out:
# sat_17
#
# Minimum Values:
#  State                                 Alabama
# Participation                            0.02
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object
#
# Maximum Values:
#  State                                 Wyoming
# Participation                             1.0
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object
#
#
# sat_18
#
# Minimum Values:
#  State                                 Alabama
# Participation                            0.02
# Evidence-Based Reading and Writing        480
# Math                                      480
# Total                                     977
# dtype: object
#
# Maximum Values:
#  State                                 Wyoming
# Participation                             1.0
# ...

# %% [markdown]
# * Correct 2017 sat math score below threshold

# %%
# look at math scores in 2017 SAT scores

math_min = sat_17['Math'] < 400
sat_17[math_min]
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536    52   1060

# %%
# Impute correct math value as Math = Total - EBRW
sat_17.loc[20, 'Math'] = sat_17.loc[20, 'Total'] - sat_17.loc[20, 'Evidence-Based Reading and Writing']

# %%
# Check to make sure value is valid
sat_17.loc[20]
# Out:
# State                                 Maryland
# Participation                             0.69
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %% [markdown]
# * Correct ACT Science Score That is Unusually Low

# %%
# View rows with unusually low science scores
low_science_mask = act_17['Science'] < 10
act_17[low_science_mask]
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 21  Maryland           0.28     23.3  23.1     24.2      2.3       23.6

# %%
# Check to make sure value has been changed
low_science_mask = act_17['Science'] < 10
act_17[low_science_mask]
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 21  Maryland           0.28     23.3  23.1     24.2      2.3       23.6

# %%
# Impute an estimated correct science score by making Science = (4 * Composite) - sum(English, Math, Reading)

if act_17.loc[21, 'Science'] == 2.3:
    act_17.loc[21, 'Science'] = round((4 * act_17.loc[21, 'Composite']) - sum(act_17.loc[21, ['English', 'Math', 'Reading']]), 1)

# %% [markdown]
# #### Drop Unneeded Columns

# %%
# Use dropdrop_unnamed_cols() function to drop unnamed columns from spending dataframes
drop_unnamed_cols(spending_dfs)
# Out:
# ed_17
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']
#
#
# ed_18
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']
#
#
# ed_19
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']
#
#
# wf_17
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']
#
#
# wf_18
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']
#
#
# wf_19
# dropped ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', ' ']

# %%
# Drop groth % columns from all spending dataframes
for df in spending_dfs:
    for col in df.columns:
        if 'growth' in col.lower() or 'product' in col.lower():
            df.drop(columns=col, inplace=True)
            print(namestr(df)[0])
            print(f'dropped {col}')
# Out:
# ed_17
# dropped Gross State Product
# ed_17
# dropped Real State Growth %
# ed_18
# dropped Gross State Product
# ed_18
# dropped Real State Growth %
# ed_19
# dropped Gross State Product
# ed_19
# dropped Real State Growth %
# wf_17
# dropped Gross State Product
# wf_17
# dropped Real State Growth %
# wf_18
# dropped Gross State Product
# wf_18
# dropped Real State Growth %
# wf_19
# dropped Gross State Product
# wf_19
# dropped Real State Growth %

# %%
# Use drop_sections function to drop all but state, participation, and total/composite columns from test score dataframes
drop_sections(score_dfs)
# Out:
# sat_17
# dropped: ['Evidence-Based Reading and Writing', 'Math']
# sat_18
# dropped: ['Evidence-Based Reading and Writing', 'Math']
# sat_19
# dropped: ['EBRW', 'Math']
# act_17
# dropped: ['English', 'Math', 'Reading', 'Science']
# act_18
# dropped: []
# act_19
# dropped: []

# %% [markdown]
# #### Rename Columns

# %%
# format all columns to be lowercase with no spaces
for df in all_dfs:
    new_cols = [col.lower().replace(' ', '_') for col in df.columns]
    df.columns = new_cols
    print('\n' + namestr(df)[0])
    print(df.columns)
# Out:
# sat_17
# Index(['state', 'participation', 'total'], dtype='object')
#
# sat_18
# Index(['state', 'participation', 'total'], dtype='object')
#
# sat_19
# Index(['state', 'participation_rate', 'total'], dtype='object')
#
# act_17
# Index(['state', 'participation', 'composite'], dtype='object')
#
# act_18
# Index(['state', 'participation', 'composite'], dtype='object')
#
# act_19
# Index(['state', 'participation', 'composite'], dtype='object')
#
# ed_17
# Index(['state', 'state_spending', 'local_spending', 'state_and_local_spending',
#        'population_(million)'],
#       dtype='object')
#
# ed_18
# Index(['state', 'state_spending', 'local_spending', 'state_and_local_spending',
#        'population_(million)'],
#       dtype='object')
#
# ed_19
# Index(['state', 'state_spending', 'local_spending', 'state_and_local_spending',
#        'population_(million)'],
#       dtype='object')
#
# wf_17
# Index(['state', 'state_spending', 'local_spending', 'state_and_local_spending',
# ...

# %%
# make sat_19 columns match sat_17 and sat_18
sat_19.columns = sat_18.columns
sat_19.columns
# Out:
# Index(['state', 'participation', 'total'], dtype='object')

# %% [markdown]
# #### Convert Spending Features to Per Capita Values

# %%
for df in spending_dfs:
    s = [col for col in df.columns if 'spending' in col]
    for column in s:
        df[column] = round(1000 * df[column] / df['population_(million)'], 2)

# %%
for df in spending_dfs:
    df.drop(columns='population_(million)', inplace=True)

# %%
ed_17
# Out:
#                    state  state_spending  local_spending  \
# 0                Alabama         1265.31         1612.24
# 1                 Alaska         2000.00         2714.29
# 2                Arizona          814.29         1371.43
# 3               Arkansas         1066.67         1733.33
# 4             California          916.03         2463.10
# 5               Colorado         1285.71         1875.00
# 6            Connecticut         1138.89         2638.89
# 7               Delaware         1900.00         2100.00
# 8   District of Columbia            0.00         4285.71
# 9                Florida          538.10         1523.81
# 10               Georgia          788.46         1923.08
# 11                Hawaii         2428.57            0.00
# 12                 Idaho          705.88         1411.76
# 13              Illinois          664.06         2351.56
# 14               Indiana         1134.33         1582.09
# ...

# %% [markdown]
# #### Merge DataFrames

# %%
# Strip whitespace from state column in all dataframes

for df in all_dfs:
    df['state'] = df['state'].apply(lambda x: x.strip())

# %%
#merge sat dataframes on state and add test and year suffixes
comb_sat = pd.merge(left=pd.merge(left=sat_17, right=sat_18, on='state', suffixes=[None, '_sat_18']), right=sat_19, on='state', suffixes=['_sat_17', '_sat_19'])
comb_sat.head()
# Out:
#         state  participation_sat_17  total_sat_17  participation_sat_18  \
# 0     Alabama                  0.05          1165                  0.06
# 1      Alaska                  0.38          1080                  0.43
# 2     Arizona                  0.30          1116                  0.29
# 3    Arkansas                  0.03          1208                  0.05
# 4  California                  0.53          1055                  0.60
#
#    total_sat_18  participation_sat_19  total_sat_19
# 0          1166                  0.07          1143
# 1          1106                  0.41          1097
# 2          1149                  0.31          1134
# 3          1169                  0.06          1141
# 4          1076                  0.63          1065

# %%
#merge sat dataframes on state and add test and year suffixes
comb_act = pd.merge(left=pd.merge(left=act_17, right=act_18, on='state', suffixes=[None, '_act_18']), right=act_19, on='state', suffixes=['_act_17', '_act_19'])
comb_act.head()
# Out:
#         state  participation_act_17  composite_act_17  participation_act_18  \
# 0     Alabama                  1.00              19.2                  1.00
# 1      Alaska                  0.65              19.8                  0.33
# 2     Arizona                  0.62              19.7                  0.66
# 3    Arkansas                  1.00              19.4                  1.00
# 4  California                  0.31              22.8                  0.27
#
#    composite_act_18  participation_act_19  composite_act_19
# 0              19.1                  1.00              18.9
# 1              20.8                  0.38              20.1
# 2              19.2                  0.73              19.0
# 3              19.4                  1.00              19.3
# 4              22.7                  0.23              22.6

# %%
#merge all test score dataframes
comb_scores = pd.merge(left=comb_act, right=comb_sat, on='state')

# %%
comb_ed = pd.merge(left=pd.merge(left=ed_17, right=ed_18, on='state', suffixes=[None, '_ed_18']), right=ed_19, on='state', suffixes=['_ed_17', '_ed_19'])
comb_ed.head()
# Out:
#         state  state_spending_ed_17  local_spending_ed_17  \
# 0     Alabama               1265.31               1612.24
# 1      Alaska               2000.00               2714.29
# 2     Arizona                814.29               1371.43
# 3    Arkansas               1066.67               1733.33
# 4  California                916.03               2463.10
#
#    state_and_local_spending_ed_17  state_spending_ed_18  local_spending_ed_18  \
# 0                         2897.96               1367.35               1653.06
# 1                         4714.29               2000.00               2714.29
# 2                         2185.71                833.33               1375.00
# 3                         2800.00               1133.33               1800.00
# 4                         3379.13                969.54               2652.28
#
#    state_and_local_spending_ed_18  state_spending_ed_19  local_spending_ed_19  \
# ...

# %%
comb_wf = pd.merge(left=pd.merge(left=wf_17, right=wf_18, on='state', suffixes=[None, '_wf_18']), right=wf_19, on='state', suffixes=['_wf_17', '_wf_19'])
comb_wf.head()
# Out:
#         state  state_spending_wf_17  local_spending_wf_17  \
# 0     Alabama                469.39                122.45
# 1      Alaska               1000.00                285.71
# 2     Arizona                514.29                 71.43
# 3    Arkansas                266.67                 66.67
# 4  California                419.85                674.30
#
#    state_and_local_spending_wf_17  state_spending_wf_18  local_spending_wf_18  \
# 0                          571.43                224.49                122.45
# 1                         1285.71               1142.86                285.71
# 2                          585.71                500.00                 69.44
# 3                          333.33                266.67                 66.67
# 4                         1096.69                428.93                708.12
#
#    state_and_local_spending_wf_18  state_spending_wf_19  local_spending_wf_19  \
# ...

# %%
comb_spending = pd.merge(left=comb_ed, right=comb_wf, on='state')
comb_spending.head()
# Out:
#         state  state_spending_ed_17  local_spending_ed_17  \
# 0     Alabama               1265.31               1612.24
# 1      Alaska               2000.00               2714.29
# 2     Arizona                814.29               1371.43
# 3    Arkansas               1066.67               1733.33
# 4  California                916.03               2463.10
#
#    state_and_local_spending_ed_17  state_spending_ed_18  local_spending_ed_18  \
# 0                         2897.96               1367.35               1653.06
# 1                         4714.29               2000.00               2714.29
# 2                         2185.71                833.33               1375.00
# 3                         2800.00               1133.33               1800.00
# 4                         3379.13                969.54               2652.28
#
#    state_and_local_spending_ed_18  state_spending_ed_19  local_spending_ed_19  \
# ...

# %%
comb_scores_spending = pd.merge(left=comb_scores, right=comb_spending, on='state')
comb_scores_spending.head()
# Out:
#         state  participation_act_17  composite_act_17  participation_act_18  \
# 0     Alabama                  1.00              19.2                  1.00
# 1      Alaska                  0.65              19.8                  0.33
# 2     Arizona                  0.62              19.7                  0.66
# 3    Arkansas                  1.00              19.4                  1.00
# 4  California                  0.31              22.8                  0.27
#
#    composite_act_18  participation_act_19  composite_act_19  \
# 0              19.1                  1.00              18.9
# 1              20.8                  0.38              20.1
# 2              19.2                  0.73              19.0
# 3              19.4                  1.00              19.3
# 4              22.7                  0.23              22.6
#
#    participation_sat_17  total_sat_17  participation_sat_18  ...  \
# 0                  0.05          1165                  0.06  ...
# ...

# %%
#add year suffix to all values in state columns before concatenating
for df in all_dfs:
    df['state'] = df['state'].apply(lambda x: x + namestr(df)[0][-3:])

# %%
#concatenate sat score dataframes
concat_sat = pd.concat(sat_dfs)

# %%
#concatenate act score dataframes
concat_act = pd.concat(act_dfs)

# %%
#merge concatenated test score dataframes into a single dataframe
merged_scores = pd.merge(left=concat_sat, right = concat_act, on='state', suffixes=['_sat', '_act'])

# %%
#concatenate education spending dataframes
concat_ed = pd.concat(ed_dfs)

# %%
#concatenate welfare spending dataframes
concat_wf = pd.concat(wf_dfs)

# %%
#merge public spending dataframes
merged_spending = pd.merge(left=concat_ed, right=concat_wf, on='state', suffixes=['_education', '_welfare'])

# %%
#merge all dataframes into a single dataframe with each row corresponding to observations in a particular state in a given year and each column corresponding to an observed test score, participation rate, or per capita spending
merged_scores_spending = pd.merge(merged_scores, merged_spending)

# %%
#add clarity to column names for test score totals
merged_scores_spending.rename(columns={'total': 'total_sat', 'composite': 'composite_act'}, inplace=True)

# %%
#add a total spending column
merged_scores_spending['total_education_and_welfare_spending'] = merged_scores_spending['state_and_local_spending_education'] + merged_scores_spending['state_and_local_spending_welfare']

# %%
# Export cleaned and merged dataframe to a new csv file
merged_scores_spending.to_csv('../data/combined_test_scores_and_public_spending_17_19.csv', index=False)
merged_scores_spending.columns
# Out:
# Index(['state', 'participation_sat', 'total_sat', 'participation_act',
#        'composite_act', 'state_spending_education', 'local_spending_education',
#        'state_and_local_spending_education', 'state_spending_welfare',
#        'local_spending_welfare', 'state_and_local_spending_welfare',
#        'total_education_and_welfare_spending'],
#       dtype='object')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ### Data Dictionary
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|object|SAT Scores 2017-2019|U.S. State with year of observations appended to the end|
# |**participation_sat**|float|SAT Scores 2017-2019|The percentage of graduating students in a given state who took the SAT|
# |**total_sat**|int|SAT Scores 2017-2019|The average total ACT score for students in a given state in a given year|
# |**participation_act**|float|ACT Scores 2017-2019|The percentage of graduation students in a given state who took the ACT|
# |**composite_act**|float|ACT Scores 2017-2019|The average composite ACT score for students in a given state in a given year|
# |**state_spending_education**|float|State and Local Education Spending 2017-2019|State education spending per capita for a given year|
# |**local_spending_education**|float|State and Local Education Spending 2017-2019|Local education spending per capita for a given year in a given state|
# |**state_and_local_spending_education**|float|State and Local Education Spending 2017-2019|Sum of state and local education spending for a given year|
# |**state_spending_welfare**|float|State and Local Education Spending 2017-2019|State spending on public welfare per capita in a given year|
# |**local_spending_welfare**|float|State and Local Education Spending 2017-2019|Local spending on public welfare per capita for a given state in a given year|
# |**state_and_local_spending_welfare**|float|State and Local Education Spending 2017-2019|Sum of state and local welfare spending per capita in a given year|
# |**total_education_and_welfare_spending**|float|State and Local Education Spending 2017-2019|Total education and welfare spending per captia for a given state in a given year|
#
#
# **State and Local Welfare/Education Spending data was sourced from:** https://www.usgovernmentspending.com/compare_state_spending_2017b40a

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# * Summary Statistics

# %%
merged_scores_spending.describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count         153.000000   153.000000          153.00000     153.000000
# mean            0.449150  1119.967320            0.61719      21.496078
# std             0.371572    93.848101            0.33675       2.099213
# min             0.020000   943.000000            0.06000      17.700000
# 25%             0.040000  1053.000000            0.29000      19.800000
# 50%             0.500000  1099.000000            0.66000      21.300000
# 75%             0.760000  1210.000000            1.00000      23.700000
# max             1.000000  1298.000000            1.00000      25.600000
#
#        state_spending_education  local_spending_education  \
# count                153.000000                153.000000
# mean                1114.620327               2160.449477
# std                  393.362306                659.243496
# min                    0.000000                  0.000000
# ...

# %%
act_75_df.describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count          63.000000    63.000000          63.000000      63.000000
# mean            0.132857  1185.523810           0.974444      19.747619
# std             0.178853    83.808318           0.060928       0.961326
# min             0.020000   963.000000           0.770000      17.700000
# 25%             0.030000  1115.500000           1.000000      19.050000
# 50%             0.040000  1210.000000           1.000000      19.800000
# 75%             0.105000  1247.500000           1.000000      20.300000
# max             0.680000  1298.000000           1.000000      21.900000
#
#        state_spending_education  local_spending_education  \
# count                 63.000000                 63.000000
# mean                1167.336349               1890.346508
# std                  410.041337                630.010203
# min                  664.060000                  0.000000
# ...

# %%
# Dictionary with standard deviation values for all numeric columns
sd = {col: s_dev(merged_scores_spending[col]) for col in merged_scores_spending.columns if col != 'state'}
sd
# Out:
# {'participation_sat': 0.3715719589450134,
#  'total_sat': 93.84810083465597,
#  'participation_act': 0.33675005864169344,
#  'composite_act': 2.099212958810904,
#  'state_spending_education': 393.36230628996583,
#  'local_spending_education': 659.2434959978856,
#  'state_and_local_spending_education': 680.8461243200886,
#  'state_spending_welfare': 263.83337606393246,
#  'local_spending_welfare': 399.20838807873037,
#  'state_and_local_spending_welfare': 430.435266157284,
#  'total_education_and_welfare_spending': 986.0794052737098}

# %%
# sort by highest sat scores
merged_scores_spending.sort_values(by=['total_sat', 'state'], ascending=False).head(15)
# Out:
#                state  participation_sat  total_sat  participation_act  \
# 74      Minnesota_18               0.04       1298               0.99
# 23      Minnesota_17               0.03       1295               1.00
# 100     Wisconsin_18               0.03       1294               1.00
# 49      Wisconsin_17               0.03       1291               1.00
# 125     Minnesota_19               0.04       1284               0.95
# 151     Wisconsin_19               0.03       1283               1.00
# 85   North Dakota_18               0.02       1283               0.98
# 15           Iowa_17               0.02       1275               0.67
# 25       Missouri_17               0.03       1271               1.00
# 143  South Dakota_19               0.03       1268               0.75
# 66         Kansas_18               0.04       1265               0.71
# 65           Iowa_18               0.03       1265               0.68
# ...

# %%
# sort by lowest sat scores
merged_scores_spending.sort_values(by=['total_sat', 'state'], ascending=True).head(15)
# Out:
#                        state  participation_sat  total_sat  participation_act  \
# 150         West Virginia_19               0.99        943               0.49
# 8    District of Columbia_17               1.00        950               0.32
# 138              Oklahoma_19               0.22        963               1.00
# 110  District of Columbia_19               0.94        975               0.32
# 109              Delaware_19               1.00        985               0.13
# 114                 Idaho_19               1.00        993               0.31
# 141          Rhode Island_19               1.00        995               0.12
# 7                Delaware_17               1.00        996               0.18
# 58               Delaware_18               1.00        998               0.17
# 111               Florida_19               1.00        999               0.54
# 99          West Virginia_18               0.28        999               0.65
# ...

# %%
#sort by highest act score
merged_scores_spending.sort_values(by=['composite_act', 'state'], ascending=False).head(15)
# Out:
#                 state  participation_sat  total_sat  participation_act  \
# 57     Connecticut_18               1.00       1053               0.26
# 29   New Hampshire_17               0.96       1052               0.18
# 123  Massachusetts_19               0.81       1120               0.21
# 72   Massachusetts_18               0.80       1125               0.25
# 108    Connecticut_19               1.00       1046               0.22
# 21   Massachusetts_17               0.76       1107               0.29
# 6      Connecticut_17               1.00       1041               0.31
# 80   New Hampshire_18               0.96       1063               0.16
# 131  New Hampshire_19               0.95       1059               0.14
# 141   Rhode Island_19               1.00        995               0.12
# 134       New York_19               0.79       1064               0.22
# 83        New York_18               0.79       1068               0.27
# ...

# %%
#sort by lowest act score
merged_scores_spending.sort_values(by=['composite_act', 'state'], ascending=True).head(15)
# Out:
#                  state  participation_sat  total_sat  participation_act  \
# 79           Nevada_18               0.23       1140               1.00
# 28           Nevada_17               0.26       1116               1.00
# 130          Nevada_19               0.20       1156               1.00
# 91   South Carolina_18               0.55       1070               1.00
# 126     Mississippi_19               0.03       1237               1.00
# 24      Mississippi_17               0.02       1242               1.00
# 75      Mississippi_18               0.03       1236               1.00
# 40   South Carolina_17               0.50       1064               1.00
# 120       Louisiana_19               0.05       1200               1.00
# 142  South Carolina_19               0.68       1030               0.78
# 102         Alabama_19               0.07       1143               1.00
# 61           Hawaii_18               0.56       1010               0.89
# ...

# %%
#states with 100% participation on sat
sat_100_mask = merged_scores_spending['participation_sat'] == 1.00
merged_scores_spending[sat_100_mask].sort_values(by='state')
# Out:
#                        state  participation_sat  total_sat  participation_act  \
# 56               Colorado_18                1.0       1025               0.30
# 107              Colorado_19                1.0       1024               0.27
# 6             Connecticut_17                1.0       1041               0.31
# 57            Connecticut_18                1.0       1053               0.26
# 108           Connecticut_19                1.0       1046               0.22
# 7                Delaware_17                1.0        996               0.18
# 58               Delaware_18                1.0        998               0.17
# 109              Delaware_19                1.0        985               0.13
# 8    District of Columbia_17                1.0        950               0.32
# 111               Florida_19                1.0        999               0.54
# 62                  Idaho_18                1.0       1001               0.36
# ...

# %%
#states with 100% participation on act
act_100_mask = merged_scores_spending['participation_act'] == 1.00
merged_scores_spending[act_100_mask].sort_values(by='state')
# Out:
#                  state  participation_sat  total_sat  participation_act  \
# 0           Alabama_17               0.05       1165                1.0
# 51          Alabama_18               0.06       1166                1.0
# 102         Alabama_19               0.07       1143                1.0
# 3          Arkansas_17               0.03       1208                1.0
# 54         Arkansas_18               0.05       1169                1.0
# 105        Arkansas_19               0.06       1141                1.0
# 5          Colorado_17               0.11       1201                1.0
# 17         Kentucky_17               0.04       1247                1.0
# 67         Kentucky_18               0.04       1248                1.0
# 119        Kentucky_19               0.04       1232                1.0
# 18        Louisiana_17               0.04       1198                1.0
# 68        Louisiana_18               0.04       1210                1.0
# ...

# %%
#states with > 50% participation on both tests
act_50_mask = merged_scores_spending['participation_act'] > 0.5
sat_50_mask = merged_scores_spending['participation_sat'] > 0.5

merged_scores_spending[act_50_mask & sat_50_mask].sort_values(by='state')
# Out:
#                  state  participation_sat  total_sat  participation_act  \
# 9           Florida_17               0.83       1017               0.73
# 59          Florida_18               0.56       1099               0.66
# 111         Florida_19               1.00        999               0.54
# 10          Georgia_17               0.61       1050               0.55
# 60          Georgia_18               0.70       1064               0.53
# 11           Hawaii_17               0.55       1085               0.90
# 61           Hawaii_18               0.56       1010               0.89
# 113          Hawaii_19               0.54       1100               0.80
# 84   North Carolina_18               0.52       1098               1.00
# 135  North Carolina_19               0.51       1100               1.00
# 91   South Carolina_18               0.55       1070               1.00
# 142  South Carolina_19               0.68       1030               0.78
#
# ...

# %%
#sort by total spending per capita
merged_scores_spending.sort_values(by='total_education_and_welfare_spending', ascending=False).head(10)
# Out:
#                        state  participation_sat  total_sat  participation_act  \
# 110  District of Columbia_19               0.94        975               0.32
# 147               Vermont_19               0.66       1106               0.20
# 8    District of Columbia_17               1.00        950               0.32
# 96                Vermont_18               0.64       1120               0.24
# 45                Vermont_17               0.60       1114               0.29
# 52                 Alaska_18               0.43       1106               0.33
# 1                  Alaska_17               0.38       1080               0.65
# 134              New York_19               0.79       1064               0.22
# 50                Wyoming_17               0.03       1230               1.00
# 83               New York_18               0.79       1068               0.27
#
#      composite_act  state_spending_education  local_spending_education  \
# ...

# %%
# sort by total education spending per capita
merged_scores_spending.sort_values(by='state_and_local_spending_education', ascending=False).head(10)
# Out:
#            state  participation_sat  total_sat  participation_act  \
# 147   Vermont_19               0.66       1106               0.20
# 50    Wyoming_17               0.03       1230               1.00
# 96    Vermont_18               0.64       1120               0.24
# 45    Vermont_17               0.60       1114               0.29
# 134  New York_19               0.79       1064               0.22
# 52     Alaska_18               0.43       1106               0.33
# 1      Alaska_17               0.38       1080               0.65
# 152   Wyoming_19               0.03       1238               1.00
# 101   Wyoming_18               0.03       1257               1.00
# 83   New York_18               0.79       1068               0.27
#
#      composite_act  state_spending_education  local_spending_education  \
# 147           24.1                   1833.33                   3666.67
# 50            20.2                   1500.00                   3666.67
# ...

# %%
# sort by total welfare spending per capita
merged_scores_spending.sort_values(by='state_and_local_spending_welfare', ascending=False).head(10)
# Out:
#                        state  participation_sat  total_sat  participation_act  \
# 110  District of Columbia_19               0.94        975               0.32
# 8    District of Columbia_17               1.00        950               0.32
# 45                Vermont_17               0.60       1114               0.29
# 96                Vermont_18               0.64       1120               0.24
# 147               Vermont_19               0.66       1106               0.20
# 139                Oregon_19               0.51       1112               0.42
# 52                 Alaska_18               0.43       1106               0.33
# 88                 Oregon_18               0.48       1117               0.42
# 37                 Oregon_17               0.43       1108               0.40
# 1                  Alaska_17               0.38       1080               0.65
#
#      composite_act  state_spending_education  local_spending_education  \
# ...

# %%
# create masked dataframes for easier vizualization of trends

#masks for act and sat participation rates over 75%
act_75_mask = merged_scores_spending['participation_act'] > .75
sat_75_mask = merged_scores_spending['participation_sat'] > .75

#masks for act and sat average scores below the mean average score
low_act_mask = merged_scores_spending['composite_act'] < merged_scores_spending['composite_act'].mean()
low_sat_mask = merged_scores_spending['total_sat'] < merged_scores_spending['total_sat'].mean()

#masks removing data points beyond 3 standard deviations above the mean in spending categories if needed
def mask_upper_outliers(column, df=merged_scores_spending):
    print('Outliers:')
    print(df[df[column] > df[column].mean() + (3 * s_dev(df[column]))][column])
    return df[column] < df[column].mean() + (3 * s_dev(df[column]))

ts_mask = mask_upper_outliers('total_education_and_welfare_spending')
st_ed_mask = mask_upper_outliers('state_spending_education')
l_ed_mask = mask_upper_outliers('local_spending_education')
st_wf_mask = mask_upper_outliers('state_spending_welfare')
l_wf_mask = mask_upper_outliers('local_spending_welfare')
stl_ed_mask = mask_upper_outliers('state_and_local_spending_education')
stl_wf_mask = mask_upper_outliers('state_and_local_spending_welfare')
# Out:
# Outliers:
# 110    8571.43
# 147    7000.00
# Name: total_education_and_welfare_spending, dtype: float64
# Outliers:
# 11     2428.57
# 61     2642.86
# 113    2714.29
# Name: state_spending_education, dtype: float64
# Outliers:
# 8      4285.71
# 110    4571.43
# Name: local_spending_education, dtype: float64
# Outliers:
# 45     1500.00
# 96     1333.33
# 139    1285.71
# 147    1333.33
# Name: state_spending_welfare, dtype: float64
# Outliers:
# 8      2571.43
# 110    4000.00
# Name: local_spending_welfare, dtype: float64
# Outliers:
# 147    5500.0
# Name: state_and_local_spending_education, dtype: float64
# Outliers:
# 8      2571.43
# 110    4000.00
# Name: state_and_local_spending_welfare, dtype: float64

# %%
# 
merged_scores_spending[act_75_mask & stl_wf_mask].sort_values(by='state_and_local_spending_welfare')[:25].describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count          25.000000    25.000000          25.000000       25.00000
# mean            0.168800  1177.240000           0.984000       19.34000
# std             0.217262    68.509294           0.055678        0.67082
# min             0.020000  1030.000000           0.780000       18.30000
# 25%             0.040000  1141.000000           1.000000       18.80000
# 50%             0.050000  1198.000000           1.000000       19.20000
# 75%             0.100000  1236.000000           1.000000       19.80000
# max             0.680000  1271.000000           1.000000       20.80000
#
#        state_spending_education  local_spending_education  \
# count                  25.00000                 25.000000
# mean                 1017.73080               1773.307600
# std                   207.67558                121.613679
# min                   672.13000               1462.690000
# ...

# %%
merged_scores_spending[act_75_mask & stl_wf_mask].sort_values(by='state_and_local_spending_welfare', ascending=False)[:25].describe()
# Out:
#        participation_sat   total_sat  participation_act  composite_act  \
# count          25.000000    25.00000          25.000000       25.00000
# mean            0.112800  1212.80000           0.951600       20.38800
# std             0.170868    81.99187           0.074144        0.88427
# min             0.020000  1010.00000           0.770000       18.90000
# 25%             0.030000  1165.00000           0.930000       20.00000
# 50%             0.030000  1240.00000           1.000000       20.30000
# 75%             0.090000  1283.00000           1.000000       21.30000
# max             0.560000  1298.00000           1.000000       21.90000
#
#        state_spending_education  local_spending_education  \
# count                 25.000000                 25.000000
# mean                1324.353600               2020.002000
# std                  542.486861                873.928237
# min                  664.060000                  0.000000
# ...

# %%
merged_scores_spending[sat_75_mask & stl_wf_mask].sort_values(by='state_and_local_spending_welfare')[:25].describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count          25.000000    25.000000          25.000000      25.000000
# mean            0.953200  1025.280000           0.298000      23.512000
# std             0.076306    36.255482           0.138203       1.582803
# min             0.760000   943.000000           0.130000      19.800000
# 25%             0.950000  1001.000000           0.190000      22.500000
# 50%             1.000000  1017.000000           0.280000      23.900000
# 75%             1.000000  1053.000000           0.350000      24.300000
# max             1.000000  1094.000000           0.730000      25.600000
#
#        state_spending_education  local_spending_education  \
# count                 25.000000                 25.000000
# mean                1091.366000               2177.354000
# std                  407.020864                483.029476
# min                  538.100000               1388.890000
# ...

# %%
merged_scores_spending[sat_75_mask & stl_wf_mask].sort_values(by='state_and_local_spending_welfare', ascending=False)[:25].describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count          25.000000    25.000000           25.00000      25.000000
# mean            0.916800  1045.640000            0.21640      24.352000
# std             0.094239    43.784396            0.10173       1.138025
# min             0.760000   943.000000            0.06000      20.800000
# 25%             0.820000  1013.000000            0.15000      24.000000
# 50%             0.960000  1052.000000            0.22000      24.400000
# 75%             1.000000  1068.000000            0.28000      25.200000
# max             1.000000  1125.000000            0.49000      25.600000
#
#        state_spending_education  local_spending_education  \
# count                 25.000000                 25.000000
# mean                 997.135600               2517.265600
# std                  266.373892                547.171029
# min                  606.300000               1777.780000
# ...

# %%
merged_scores_spending[sat_75_mask & stl_wf_mask].sort_values(by='state_and_local_spending_welfare').describe()
# Out:
#        participation_sat    total_sat  participation_act  composite_act  \
# count          37.000000    37.000000          37.000000      37.000000
# mean            0.937027  1033.000000           0.258108      23.889189
# std             0.087142    40.860875           0.137272       1.440830
# min             0.760000   943.000000           0.060000      19.800000
# 25%             0.830000  1005.000000           0.170000      23.800000
# 50%             0.990000  1018.000000           0.250000      24.200000
# 75%             1.000000  1059.000000           0.310000      24.700000
# max             1.000000  1125.000000           0.730000      25.600000
#
#        state_spending_education  local_spending_education  \
# count                 37.000000                 37.000000
# mean                1026.836216               2304.132973
# std                  356.648498                579.936391
# min                  538.100000               1388.890000
# ...

# %% [markdown]
# **Trends**
# * The clearest trend in the data explored above is the relationship between participation and test scores. There is a strong negative correlation between participation rates and test scores that is evident even before calculating the correlation coefficient. The highest 30 average scores on the SAT between 2017 and 2019 all had participation rates lower than 5%.
# * Participation rates in general are higher for the act than the sat. The act had an average participation rate of 61.7% between 2017 and 2019 while the average for the sat was only 44.9%. The act also recorded a much higher number of states with 100% participation between 2017 and 2019 than the sat with a total of 49 occurances compared to just 17 for the sat.
# * High participation rates on one test seem to correlate with low participation rates on the other, and test scores seem to follow the same trend.
# * States tend to spend significantly more per capita on education than on welfare, though it appears there are some major outliers in welfare spending such as the District of Columbia whose public spending in 2019 was 7.58 standard deviations above the mean.
# * No obvious trends were immediately present in the relationships between public spending and standardized test scores.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# create masked dataframes for easier vizualization of trends

#masks for act and sat participation rates over 75%
act_75_mask = merged_scores_spending['participation_act'] > .75
sat_75_mask = merged_scores_spending['participation_sat'] > .75

#masks for act and sat average scores below the mean average score
low_act_mask = merged_scores_spending['composite_act'] < merged_scores_spending['composite_act'].mean()
low_sat_mask = merged_scores_spending['total_sat'] < merged_scores_spending['total_sat'].mean()

#masks removing data points beyond 3 standard deviations above the mean in spending categories
def mask_upper_outliers(column, df=merged_scores_spending):
    print('Outliers:')
    print(df[df[column] > df[column].mean() + (3 * s_dev(df[column]))][column])
    return df[column] < df[column].mean() + (3 * s_dev(df[column]))

ts_mask = mask_upper_outliers('total_education_and_welfare_spending')
st_ed_mask = mask_upper_outliers('state_spending_education')
l_ed_mask = mask_upper_outliers('local_spending_education')
st_wf_mask = mask_upper_outliers('state_spending_welfare')
l_wf_mask = mask_upper_outliers('local_spending_welfare')
stl_ed_mask = mask_upper_outliers('state_and_local_spending_education')
stl_wf_mask = mask_upper_outliers('state_and_local_spending_welfare')
# Out:
# Outliers:
# 110    8571.43
# 147    7000.00
# Name: total_education_and_welfare_spending, dtype: float64
# Outliers:
# 11     2428.57
# 61     2642.86
# 113    2714.29
# Name: state_spending_education, dtype: float64
# Outliers:
# 8      4285.71
# 110    4571.43
# Name: local_spending_education, dtype: float64
# Outliers:
# 45     1500.00
# 96     1333.33
# 139    1285.71
# 147    1333.33
# Name: state_spending_welfare, dtype: float64
# Outliers:
# 8      2571.43
# 110    4000.00
# Name: local_spending_welfare, dtype: float64
# Outliers:
# 147    5500.0
# Name: state_and_local_spending_education, dtype: float64
# Outliers:
# 8      2571.43
# 110    4000.00
# Name: state_and_local_spending_welfare, dtype: float64

# %%
c_values = round(merged_scores_spending.corr(), 2)

mask = np.zeros_like(c_values)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(16, 12))
sns.heatmap(c_values, mask=mask, annot=True,square=True, cmap='bone');

# %% [markdown]
# #### Visualizing Relationship Between Participation and Test Scores

# %%
# Plot all act scores vs act scores that correspond with more than 75% participation
plt.figure(figsize=(10,9))
plt.hist(merged_scores_spending['composite_act'], bins=12, label='All States', alpha=0.75)
plt.hist(merged_scores_spending[act_75_mask]['composite_act'], bins=9, label = 'States with > 75% Participation', alpha=0.85)
plt.axvline(merged_scores_spending['composite_act'].mean())
plt.axvline(merged_scores_spending[act_75_mask]['composite_act'].mean(), color='orange')
plt.title('Distribution of Average State ACT Scores', size=30)
plt.legend(fontsize=15)
plt.xlabel('Average ACT Score', size=25)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/distribution_of_avg_act_scores.png');

# %%
# Plot all act scores vs act scores that correspond with more than 75% participation
plt.figure(figsize=(10,9))
plt.hist(merged_scores_spending['total_sat'], bins=12, label=' All States', alpha=0.75)
plt.hist(merged_scores_spending[sat_75_mask]['total_sat'], bins=6, label='States with > 75% Participation', alpha = 0.85)
plt.axvline(merged_scores_spending['total_sat'].mean())
plt.axvline(merged_scores_spending[sat_75_mask]['total_sat'].mean(), color='orange')
plt.title('Distribution of Average SAT Scores', size=30)
plt.legend(fontsize=15)
plt.xlabel('Average SAT Score', size=25)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/distribution_of_avg_sat_scores.png');

# %%
merged_scores_spending[sat_75_mask]['total_sat'].mean()
# Out:
# 1029.3846153846155

# %% [markdown]
# As expected, participation has a strong negative correlation with test scores. The distributions of high participation scores also follow a more normal distribution, as one would expect.

# %% [markdown]
# #### Visualizing Spending Trends Among States with High Test Participation

# %%
#plot distrubution of per capita total public spending by state for states with high participation.
plt.figure(figsize=(10,9))
plt.hist(merged_scores_spending['total_education_and_welfare_spending'], 
         bins=20, 
         alpha=.75,
         label='Spending in All States'
        )
plt.hist(merged_scores_spending[sat_75_mask]['total_education_and_welfare_spending'], 
         bins=20, 
         alpha=.85,
         label='Spending in States with > 75% SAT Paricipation '
        )
plt.hist(merged_scores_spending[act_75_mask]['total_education_and_welfare_spending'], 
         bins=10, 
         alpha=0.65,
         label='Spending in States with >75% ACT Participation'
        )
plt.title('Total Education and Welfare Spending Per Capita', 
          size=30
         )
plt.legend(fontsize=15)
plt.xlabel('Spending in Dollars Per Capita', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout();

# %%
plt.figure(figsize=(10,9))
plt.hist(merged_scores_spending['state_and_local_spending_welfare'], 
         bins=30, 
         alpha=.75,
         label='Spending in All States'
        )
plt.hist(merged_scores_spending[sat_75_mask]['state_and_local_spending_welfare'], 
         bins=25, 
         alpha=.85,
         label='Spending in States with > 75% SAT Paricipation '
        )
plt.hist(merged_scores_spending[act_75_mask]['state_and_local_spending_welfare'], 
         bins=5, 
         alpha=0.65,
         label='Spending in States with >75% ACT Participation'
        )
plt.title('Total State and Local Welfare Spending Per Capita', 
          size=25
         )
plt.legend(fontsize=15)
plt.xlabel('Spending in Dollars Per Capita', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout();

# %%
plt.figure(figsize=(10,9))
plt.hist(merged_scores_spending['state_and_local_spending_education'],
         alpha=.75, 
         bins=20,
         label='Spendin in All States'
        )
plt.hist(merged_scores_spending[sat_75_mask]['state_and_local_spending_education'], 
         alpha=.85, 
         bins=20,
         label='Spending in States with > 75% SAT Participation'
        )
plt.hist(merged_scores_spending[act_75_mask]['state_and_local_spending_education'], 
         alpha=.65, 
         bins=20,
         label='Spending in States with > 75% ACT Participation'
        )
plt.title('Total State and Local Education Spending Per Capita', size=25)
plt.legend(fontsize=13)
plt.xlabel('Spending in Dollars Per Capita', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout();

# %% [markdown]
# In all three of the above histograms, higher act participation tends to correspond to lower public spending in all categories.

# %% [markdown]
# #### Visualizing ACT Scores in States with Per Capita Public Spending Above and Below the Median

# %%
act_75_df = merged_scores_spending[act_75_mask]

top_50 = act_75_df['state_and_local_spending_welfare'] > act_75_df['state_and_local_spending_welfare'].median()
bottom_50 = act_75_df['state_and_local_spending_welfare'] < act_75_df['state_and_local_spending_welfare'].median()

plt.figure(figsize=(12,9))
plt.hist(act_75_df['composite_act'], alpha=.4, bins=15, label='All ACT Scores > 75% Participation')
plt.hist(act_75_df[top_50]['composite_act'], alpha=0.85, bins=15, label='> Median Welfare Spending')
plt.hist(act_75_df[bottom_50]['composite_act'], alpha=0.65, bins=15, label='> Median Welfare Spending')
plt.axvline(act_75_df['composite_act'].mean())
plt.axvline(act_75_df[top_50]['composite_act'].mean(), color='orange')
plt.axvline(act_75_df[bottom_50]['composite_act'].mean(), color='green')
plt.legend(fontsize=13)
plt.title('ACT Scores: Top 50% and Bottom 50% of Welfare Spending', size=25)
plt.xlabel('Average ACT Score', size=20)
plt.ylabel('Frequency', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout
plt.savefig('../images/act_scores_top_bottom_50%_wf_spending.png');

# %%
# calculate mean of all act scores above 75% participation and the top and bottom 50% in terms of welfare spending
top_50 = act_75_df['state_and_local_spending_welfare'] > act_75_df['state_and_local_spending_welfare'].median()
bottom_50 = act_75_df['state_and_local_spending_welfare'] < act_75_df['state_and_local_spending_welfare'].median()

print('Mean ACT Score for All States > 75% Participation')
print(act_75_df['composite_act'].mean())
print('Mean ACT Score for States also > Median Education Spending')
print(act_75_df[top_50]['composite_act'].mean())
print('Mean ACT Score for States also < Median Education Spending')
print(act_75_df[bottom_50]['composite_act'].mean())
print(s_dev(act_75_df['composite_act']))

(act_75_df[top_50]['composite_act'].mean() - act_75_df[bottom_50]['composite_act'].mean()) / s_dev(act_75_df['composite_act'])
# Out:
# Mean ACT Score for All States > 75% Participation
# 19.747619047619047
# Mean ACT Score for States also > Median Education Spending
# 20.287096774193543
# Mean ACT Score for States also < Median Education Spending
# 19.23548387096774
# 0.9613258892996628
# 1.0939192576951344

# %%
top_50 = act_75_df['state_and_local_spending_education'] > act_75_df['state_and_local_spending_education'].median()
bottom_50 = act_75_df['state_and_local_spending_education'] < act_75_df['state_and_local_spending_education'].median()

plt.figure(figsize=(12,9))
plt.hist(act_75_df['composite_act'], alpha=.4, bins=15, label='All ACT Scores > 75% Participation')
plt.hist(act_75_df[top_50]['composite_act'], alpha=0.85, bins=15, label='> Median Education Spending')
plt.hist(act_75_df[bottom_50]['composite_act'], alpha=0.65, bins=15, label='> Median Education Spending')
plt.axvline(act_75_df['composite_act'].mean())
plt.axvline(act_75_df[top_50]['composite_act'].mean(), color='orange')
plt.axvline(act_75_df[bottom_50]['composite_act'].mean(), color='green')
plt.legend(fontsize=13)
plt.title('ACT Scores: Top 50% and Bottom 50% of Education Spending', size=25)
plt.xlabel('Average ACT Score', size=20)
plt.ylabel('Frequency', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout
plt.savefig('../images/act_scores_top_bottom_50%_ed_spending.png');

# %%
# calculate mean of all act scores above 75% participation and the top and bottom 50% in terms of education spending
top_50 = act_75_df['state_and_local_spending_education'] > act_75_df['state_and_local_spending_education'].median()
bottom_50 = act_75_df['state_and_local_spending_education'] < act_75_df['state_and_local_spending_education'].median()

print('Mean ACT Score for All States > 75% Participation')
print(act_75_df['composite_act'].mean())
print('Mean ACT Score for States also > Median Education Spending')
print(act_75_df[top_50]['composite_act'].mean())
print('Mean ACT Score for States also < Median Education Spending')
print(act_75_df[bottom_50]['composite_act'].mean())
print(s_dev(act_75_df['composite_act']))

(act_75_df[top_50]['composite_act'].mean() - act_75_df[bottom_50]['composite_act'].mean()) / s_dev(act_75_df['composite_act'])
# Out:
# Mean ACT Score for All States > 75% Participation
# 19.747619047619047
# Mean ACT Score for States also > Median Education Spending
# 20.119354838709672
# Mean ACT Score for States also < Median Education Spending
# 19.39354838709677
# 0.9613258892996628
# 0.7550056226423475

# %% [markdown]
# The above graph demonstrates one of the most interesting findings in this analysis. Among the states with at least 75% participation, those states with greater than the median per capita welfare spending had corresponding mean ACT scores over a whole point higher than states with less than the median welfare spending.

# %% [markdown]
# #### Visualizing Outliers in Spending Data

# %%
plt.figure(figsize=(24, 16))

ax1 = plt.subplot(3, 3, 1)
ax1.set_title('State Education Spending ($ per capita)', size=20)
ax1.boxplot(merged_scores_spending['state_spending_education'])

ax2 = plt.subplot(3, 3, 2)
ax2.set_title('Local Education Spending ($ per capita)', size=20)
ax2.boxplot(merged_scores_spending['local_spending_education'])

ax3 = plt.subplot(3, 3, 3)
ax3.set_title('State and Local Education Spending ($ per capita)', size=20)
ax3.boxplot(merged_scores_spending['state_and_local_spending_education'])

ax4 = plt.subplot(3, 3, 4)
ax4.set_title('State Welfare Spending ($ per capita)', size=20)
ax4.boxplot(merged_scores_spending['state_spending_welfare'])

ax5 = plt.subplot(3, 3, 5)
ax5.set_title('Local Welfare Spending ($ per capita)', size=20)
ax5.boxplot(merged_scores_spending['local_spending_welfare'])

ax6 = plt.subplot(3, 3, 6)
ax6.set_title('State and Local Welfare Spending ($ per capita)', size=20)
ax6.boxplot(merged_scores_spending['state_and_local_spending_welfare']);

# %% [markdown]
# As expected, the public spending categories contained many significant outliers. Because of the very limited amount of data with which I have to work, I chose not to remove these outliers, even though their removal would have improved the metrics I was hoping to measure.

# %% [markdown]
# #### Visualizing Relationships with Scatter Plots

# %%
# Helper function to help plot quick scatter plots
def scatter_plotter(score_mask, spend_mask, column, test):
    plt.figure(figsize=(12, 9))
    plt.scatter(x = merged_scores_spending[score_mask & spend_mask][column],
                y = merged_scores_spending[score_mask & spend_mask][test]
               )
    plt.title(test + " & " + column, size=25)

# %%
#Quickly plot several scatter plots to visualize relationships that may be interesting to explore further

l_wf_mask_2 = merged_scores_spending['local_spending_welfare'] < 900


scatter_plotter(sat_75_mask, stl_wf_mask, 'state_and_local_spending_welfare', 'total_sat')

scatter_plotter(act_75_mask, stl_wf_mask, 'state_and_local_spending_welfare', 'composite_act')

scatter_plotter(act_100_mask, stl_ed_mask, 'state_and_local_spending_education', 'composite_act')

scatter_plotter(sat_75_mask, st_wf_mask, 'state_spending_welfare', 'total_sat')

scatter_plotter(sat_75_mask, l_wf_mask_2, 'local_spending_welfare', 'total_sat')


scatter_plotter(act_100_mask, st_wf_mask, 'state_spending_welfare', 'composite_act')

scatter_plotter(act_100_mask, l_wf_mask_2, 'local_spending_welfare', 'composite_act')

# %%
plt.figure(figsize=(15, 10))

plt.scatter(merged_scores_spending[act_100_mask & stl_ed_mask]['state_and_local_spending_education'], merged_scores_spending[act_100_mask & stl_ed_mask]['composite_act']);

# %%
plt.figure(figsize=(15, 10))

plt.scatter(merged_scores_spending[act_100_mask & stl_ed_mask]['state_and_local_spending_education'], merged_scores_spending[act_100_mask & stl_ed_mask]['composite_act']);

# %%
plt.figure(figsize=(12, 8))

plt.scatter(act_75_df['state_and_local_spending_welfare'], 
            act_75_df['composite_act'],
            s=100,
            alpha=0.5
           )
plt.title('ACT Scores and Total Welfare Spending Per Capita', size=25)
plt.xlabel('Welfare Spending in Dollars Per Capita', size=20)
plt.ylabel('Average ACT Score', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/scatter_act_and_welfare.png');

# %%
plt.figure(figsize=(12, 8))

plt.scatter(act_75_df['state_and_local_spending_education'], 
            act_75_df['composite_act'],
            s=100,
            alpha=0.5
           )
plt.title('ACT Scores and Total Education Spending Per Capita', size=25)
plt.xlabel('Education Spending in Dollars Per Capita', size=20)
plt.ylabel('Average ACT Score', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/scatter_act_and_education.png');

# %% [markdown]
# The positive relationship between public spending and test scores can be seen in the above scatter plots, though perhaps not as clearly as in the layered histogram. There is very little here that suggests either welfare or education spending has a greater influence on test scores.

# %%
plt.figure(figsize=(15, 10))

plt.scatter(act_75_df['local_spending_welfare'], 
            act_75_df['composite_act'],
            s=100
           )
plt.title('ACT Scores and Local Welfare Spending Per Capita', size=25)
plt.xlabel('Welfare Spending in Dollars Per Capita', size=20)
plt.ylabel('Average ACT Score', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/scatter_act_and_local_welfare.png');

# %%
plt.figure(figsize=(15, 10))

plt.scatter(act_75_df['state_spending_welfare'], 
            act_75_df['composite_act'],
            s=100
           )
plt.title('ACT Scores and State Welfare Spending Per Capita', size=25)
plt.xlabel('Welfare Spending in Dollars Per Capita', size=20)
plt.ylabel('Average ACT Score', size=20)
plt.xticks(size=15)
plt.yticks(size=15)
plt.tight_layout()
plt.savefig('../images/scatter_act_and_local_welfare.png');

# %% [markdown]
# There is no discernable difference relationship in the isolated local and state welfare spending data. Very little insight can be gleaned from these scatter plots.

# %%
plt.figure(figsize=(12, 10))

plt.scatter(merged_scores_spending['participation_sat'], 
            merged_scores_spending['total_sat'],
            s=100,
            alpha=0.5
           )
plt.title('Relationship between Participation and SAT Scores', size=25)
plt.xlabel('State SAT Participation Rate', size=20)
plt.ylabel('Average SAT Score', size=20)
plt.tight_layout()
plt.savefig('../images/scatter_sat_participation_and_scores.png');

# %%
plt.figure(figsize=(12, 10))

plt.scatter(merged_scores_spending['participation_act'], 
            merged_scores_spending['composite_act'],
            s=100,
            alpha=0.5
           )
plt.title('Relationship between Participation and ACT Scores', size=25)
plt.xlabel('State ACT Participation Rate', size=20)
plt.ylabel('Average ACT Score', size=20)
plt.tight_layout()
plt.savefig('../images/scatter_act_participation_and_scores.png');

# %% [markdown]
# The above two scatter plots illustrate the clearest conclusion that can be drawn from the analysis performed. There is an extremely strong negative relationship between participation rates and test scores.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# #### Conclusions:
# * The clearest relationship that needs to be explored further is the relationship betwen participation rates and test scores. One can speculate that high acheiving students are more likely to go out of their way to take a test that is not required of them or strongly recommended in hopes of gaining access to a more competitive post-secondary education. Alternatively it may be the case that low income students are less likely to be made aware of fee waivers for tests that are not either required or strongly encouraged. It is likely a combination of these and other underlying factors that explain this phenomenon, but this would be a promising avenue for future research.
# * The trends in the coming 5 plus years of universities deciding to either forgo testing or continue to use standardized tests as indicators of future student achievement will likely determine the utility of further research into public welfare and education spending on SAT and ACT scores. The low participation rates in many states already cause difficulty in extracting useful insights into how changes in environmental factors influence student test scores. A continued decrease in test participation would likely make it disproportionately more difficult to gain insight into how to improve the achievement of the most disadvantaged students, as they appear to be more likely not to participate.
# * The states that ranked in the top 50% in welfare spending per capita had average test scores of roughly 1 standard deviation higher on average than states in the bottom 50% of welfare spending per capita. Education spending per capita yeilded similar results with slightly less than 1 standard deviation difference between high participation states in the top and bottom 50% of per capita spending.
# * There is support in this analysis to suggest that public welfare spending is at least as effective as education spending in its positive impact on test scores, but the findings do not suggest that one has a significantly stronger positive relationship with test scores than the other. Further research needs pursuing on the effect of different kinds of welfare spending on student achievement and what balances of education and welfare spending correspond with the greatest increase in test scores among the lowest acheiving students.
# * Given the controversies that exist around questions of education funding, public welfare programs specifically aimed at improving living conditions and indirectly improving student achievement may be a creative avenue for public fund allocation that may be more likely to gain a broader base of support across party and ideological lines and make it more likely that the most disadvantaged students benefit directly from these fund reallocations.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
